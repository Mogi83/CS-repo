# %%
import seaborn as sns

# %%
df = sns.load_dataset('penguins')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# look at numbers, 2, 2, 2
#


#Describe summary statistics
#Bill length has wide distribution with mean.
#mean of 17 with st of 2.
#look at prperties of data
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
#considers each a unique combo of values
# doesnt help.
df.groupby('sex').value_counts()
# Out:
# sex     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# Female  Adelie   Biscoe  34.5            18.1           187.0              2900.0         1
#                          35.0            17.9           190.0              3450.0         1
#                                                         192.0              3725.0         1
#                          35.3            18.9           187.0              3800.0         1
#                          35.5            16.2           195.0              3350.0         1
#                                                                                          ..
# Male    Gentoo   Biscoe  53.4            15.8           219.0              5500.0         1
#                          54.3            15.7           231.0              5650.0         1
#                          55.1            16.0           230.0              5850.0         1
# ...

# %%
#balanced set.
df.groupby('sex').count()
# Out:
#         species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# sex
# Female      165     165             165            165                165
# Male        168     168             168            168                168
#
#         body_mass_g
# sex
# Female          165
# Male            168

# %%
#found all numerical features and made a grid.

#every row is a numerical feature
sns.pairplot(df)

# %%
sns.pairplot(df, hue="island")

# %%
sns.pairplot(df, hue='sex')

# %%
sns.pairplot(df, hue='sex', markers=['o','s'])

# %%
#Body mass and bill length usefule to discriminate.
sns.scatterplot(df, x="bill_length_mm", y="body_mass_g", hue="species", style="sex")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='body_mass_g'>

# %%
#distribution between male and femaile for differne species.
sns.countplot(df, x="species", hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
#look at the skeyws
df.hist()
# Out:
# array([[<Axes: title={'center': 'bill_length_mm'}>,
#         <Axes: title={'center': 'bill_depth_mm'}>],
#        [<Axes: title={'center': 'flipper_length_mm'}>,
#         <Axes: title={'center': 'body_mass_g'}>]], dtype=object)

# %%
sns.histplot(df, x='bill_length_mm', hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.kdeplot(df, x='bill_length_mm', hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.kdeplot(df, x='bill_length_mm', hue="species", fill="true")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Density'>
